# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# importing sys
import sys
 
# adding config to the system path
sys.path.insert(0, '/Nishi/Data_BootCamp/Week6/World_Weather_Analysis')
 
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)

#cities
# Out:
# 733

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Get the weather data for 'Portland'.

new_url = url + "&q=" + "Portland"
weather = requests.get(new_url)

if weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")

# Get the json data
portland = weather.json()

# Get the weather description for 'Portland'
desc = portland["weather"][0]["description"]

portland
# Out:
# City Weather found.
# {'coord': {'lon': -122.6762, 'lat': 45.5234},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 76.57,
#   'feels_like': 76.69,
#   'temp_min': 68.97,
#   'temp_max': 81.18,
#   'pressure': 1016,
#   'humidity': 59},
#  'visibility': 10000,
#  'wind': {'speed': 1.01, 'deg': 0, 'gust': 5.01},
#  'clouds': {'all': 0},
#  'dt': 1658379003,
#  'sys': {'type': 2,
#   'id': 2008548,
#   'country': 'US',
#   'sunrise': 1658320878,
#   'sunset': 1658375547},
#  'timezone': -25200,
#  'id': 5746545,
#  'name': 'Portland',
#  'cod': 200}

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | kalmunai
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | ejura
# Processing Record 16 of Set 1 | kahului
# Processing Record 17 of Set 1 | mount isa
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | faanui
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | channel-port aux basques
# Processing Record 23 of Set 1 | takab
# Processing Record 24 of Set 1 | mandan
# Processing Record 25 of Set 1 | rocha
# Processing Record 26 of Set 1 | kidal
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | bubaque
# Processing Record 29 of Set 1 | gobabis
# Processing Record 30 of Set 1 | san rafael
# Processing Record 31 of Set 1 | richards bay
# Processing Record 32 of Set 1 | pacific grove
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | broken arrow
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | shar
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | fort saint james
# Processing Record 42 of Set 1 | las cruces
# Processing Record 43 of Set 1 | kupang
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | guerrero negro
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | sofiysk
# City not found. Skipping...
# Processing Record 49 of Set 1 | kaitangata
# Processing Record 50 of Set 1 | kismayo
# Processing Record 1 of Set 2 | havre-saint-pierre
# Processing Record 2 of Set 2 | shakawe
# Processing Record 3 of Set 2 | severo-kurilsk
# Processing Record 4 of Set 2 | ankang
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | boromo
# Processing Record 7 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 2 | pasni
# Processing Record 9 of Set 2 | lavrentiya
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | konevo
# Processing Record 13 of Set 2 | newcastle
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | jardim
# Processing Record 17 of Set 2 | san patricio
# Processing Record 18 of Set 2 | port blair
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | atar
# Processing Record 21 of Set 2 | bathsheba
# Processing Record 22 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | udachnyy
# Processing Record 26 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 2 | elko
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | teknaf
# Processing Record 30 of Set 2 | bourg-en-bresse
# Processing Record 31 of Set 2 | hamilton
# Processing Record 32 of Set 2 | sorland
# Processing Record 33 of Set 2 | esperance
# Processing Record 34 of Set 2 | saint-joseph
# Processing Record 35 of Set 2 | adrar
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | mabaruma
# Processing Record 38 of Set 2 | yerbogachen
# Processing Record 39 of Set 2 | kralendijk
# Processing Record 40 of Set 2 | lorengau
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | alofi
# Processing Record 43 of Set 2 | morondava
# Processing Record 44 of Set 2 | harper
# Processing Record 45 of Set 2 | dien bien
# City not found. Skipping...
# Processing Record 46 of Set 2 | kodinsk
# Processing Record 47 of Set 2 | tulu bolo
# Processing Record 48 of Set 2 | victoria
# Processing Record 49 of Set 2 | shimoda
# Processing Record 50 of Set 2 | cherskiy
# Processing Record 1 of Set 3 | hualmay
# Processing Record 2 of Set 3 | iquitos
# Processing Record 3 of Set 3 | mamallapuram
# Processing Record 4 of Set 3 | port hardy
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | palimbang
# Processing Record 8 of Set 3 | mehriz
# Processing Record 9 of Set 3 | roebourne
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | businga
# Processing Record 12 of Set 3 | sesheke
# Processing Record 13 of Set 3 | korla
# Processing Record 14 of Set 3 | kruisfontein
# Processing Record 15 of Set 3 | havre
# Processing Record 16 of Set 3 | fukue
# Processing Record 17 of Set 3 | yuanping
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 3 | touros
# Processing Record 23 of Set 3 | mogochin
# City not found. Skipping...
# Processing Record 24 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 25 of Set 3 | coihaique
# Processing Record 26 of Set 3 | sao joao da barra
# Processing Record 27 of Set 3 | akdepe
# Processing Record 28 of Set 3 | nhulunbuy
# Processing Record 29 of Set 3 | saint-augustin
# Processing Record 30 of Set 3 | caravelas
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | bluff
# Processing Record 33 of Set 3 | tongren
# Processing Record 34 of Set 3 | xuddur
# Processing Record 35 of Set 3 | north bend
# Processing Record 36 of Set 3 | broome
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | puerto ayora
# Processing Record 39 of Set 3 | mar del plata
# Processing Record 40 of Set 3 | samarai
# Processing Record 41 of Set 3 | lagoa
# Processing Record 42 of Set 3 | iqaluit
# Processing Record 43 of Set 3 | lebu
# Processing Record 44 of Set 3 | gat
# Processing Record 45 of Set 3 | yacuiba
# Processing Record 46 of Set 3 | homer
# Processing Record 47 of Set 3 | belyy yar
# Processing Record 48 of Set 3 | arraial do cabo
# Processing Record 49 of Set 3 | taltal
# Processing Record 50 of Set 3 | narsaq
# Processing Record 1 of Set 4 | omagari
# Processing Record 2 of Set 4 | seymchan
# Processing Record 3 of Set 4 | cayenne
# Processing Record 4 of Set 4 | bethel
# Processing Record 5 of Set 4 | moree
# Processing Record 6 of Set 4 | contamana
# Processing Record 7 of Set 4 | san jose
# Processing Record 8 of Set 4 | la palma
# Processing Record 9 of Set 4 | porto nacional
# Processing Record 10 of Set 4 | lugano
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | farmington
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 4 | ossora
# Processing Record 17 of Set 4 | luderitz
# Processing Record 18 of Set 4 | pangnirtung
# Processing Record 19 of Set 4 | port lincoln
# Processing Record 20 of Set 4 | camana
# Processing Record 21 of Set 4 | centenario do sul
# Processing Record 22 of Set 4 | lompoc
# Processing Record 23 of Set 4 | yumen
# Processing Record 24 of Set 4 | kortkeros
# Processing Record 25 of Set 4 | bilibino
# Processing Record 26 of Set 4 | andijon
# Processing Record 27 of Set 4 | santa maria
# Processing Record 28 of Set 4 | trindade
# Processing Record 29 of Set 4 | kitwe
# Processing Record 30 of Set 4 | ushtobe
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | tuatapere
# Processing Record 33 of Set 4 | leningradskiy
# Processing Record 34 of Set 4 | belmonte
# Processing Record 35 of Set 4 | bara
# Processing Record 36 of Set 4 | ballina
# Processing Record 37 of Set 4 | flinders
# Processing Record 38 of Set 4 | namwala
# Processing Record 39 of Set 4 | matameye
# City not found. Skipping...
# Processing Record 40 of Set 4 | hobyo
# Processing Record 41 of Set 4 | saskylakh
# Processing Record 42 of Set 4 | tiksi
# Processing Record 43 of Set 4 | miri
# Processing Record 44 of Set 4 | laguna
# Processing Record 45 of Set 4 | zhovti vody
# Processing Record 46 of Set 4 | tarko-sale
# Processing Record 47 of Set 4 | barra do garcas
# Processing Record 48 of Set 4 | yulara
# Processing Record 49 of Set 4 | hilo
# Processing Record 50 of Set 4 | barrow
# Processing Record 1 of Set 5 | salalah
# Processing Record 2 of Set 5 | troitsko-pechorsk
# Processing Record 3 of Set 5 | dunedin
# Processing Record 4 of Set 5 | valer
# Processing Record 5 of Set 5 | san pedro
# Processing Record 6 of Set 5 | ostrovnoy
# Processing Record 7 of Set 5 | beyneu
# Processing Record 8 of Set 5 | ribeira grande
# Processing Record 9 of Set 5 | alappuzha
# Processing Record 10 of Set 5 | half moon bay
# Processing Record 11 of Set 5 | khasan
# Processing Record 12 of Set 5 | bengkulu
# Processing Record 13 of Set 5 | vardo
# Processing Record 14 of Set 5 | la asuncion
# Processing Record 15 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 5 | leninsk
# Processing Record 17 of Set 5 | banda aceh
# Processing Record 18 of Set 5 | porto novo
# Processing Record 19 of Set 5 | kuraymah
# Processing Record 20 of Set 5 | conselheiro pena
# Processing Record 21 of Set 5 | conde
# Processing Record 22 of Set 5 | mendi
# Processing Record 23 of Set 5 | korsor
# Processing Record 24 of Set 5 | katesh
# Processing Record 25 of Set 5 | qasigiannguit
# Processing Record 26 of Set 5 | qujing
# Processing Record 27 of Set 5 | cidreira
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | sahbuz
# Processing Record 30 of Set 5 | sur
# Processing Record 31 of Set 5 | dunayivtsi
# City not found. Skipping...
# Processing Record 32 of Set 5 | mogadishu
# Processing Record 33 of Set 5 | antalaha
# Processing Record 34 of Set 5 | saint anthony
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | praya
# Processing Record 37 of Set 5 | salekhard
# Processing Record 38 of Set 5 | wanning
# Processing Record 39 of Set 5 | tucurui
# Processing Record 40 of Set 5 | pontianak
# Processing Record 41 of Set 5 | sanmenxia
# Processing Record 42 of Set 5 | castro
# Processing Record 43 of Set 5 | matamoros
# Processing Record 44 of Set 5 | alibag
# Processing Record 45 of Set 5 | guapore
# Processing Record 46 of Set 5 | mikhaylovka
# Processing Record 47 of Set 5 | saint-philippe
# Processing Record 48 of Set 5 | ilulissat
# Processing Record 49 of Set 5 | fortuna
# Processing Record 50 of Set 5 | jalu
# Processing Record 1 of Set 6 | cazaje
# City not found. Skipping...
# Processing Record 2 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 3 of Set 6 | malaryta
# Processing Record 4 of Set 6 | pitimbu
# Processing Record 5 of Set 6 | cam ranh
# Processing Record 6 of Set 6 | bud
# Processing Record 7 of Set 6 | vanavara
# Processing Record 8 of Set 6 | ulladulla
# Processing Record 9 of Set 6 | fairbanks
# Processing Record 10 of Set 6 | aklavik
# Processing Record 11 of Set 6 | djenne
# Processing Record 12 of Set 6 | miyako
# Processing Record 13 of Set 6 | arica
# Processing Record 14 of Set 6 | hargeysa
# Processing Record 15 of Set 6 | biak
# Processing Record 16 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 6 | garissa
# Processing Record 18 of Set 6 | chitipa
# Processing Record 19 of Set 6 | ewa beach
# Processing Record 20 of Set 6 | serra branca
# Processing Record 21 of Set 6 | kangaba
# Processing Record 22 of Set 6 | beringovskiy
# Processing Record 23 of Set 6 | sakakah
# Processing Record 24 of Set 6 | rangia
# Processing Record 25 of Set 6 | kavaratti
# Processing Record 26 of Set 6 | owando
# Processing Record 27 of Set 6 | tasiilaq
# Processing Record 28 of Set 6 | haines junction
# Processing Record 29 of Set 6 | tautira
# Processing Record 30 of Set 6 | port keats
# Processing Record 31 of Set 6 | tomatlan
# Processing Record 32 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 6 | billings
# Processing Record 34 of Set 6 | oktyabrskiy
# Processing Record 35 of Set 6 | tiznit
# Processing Record 36 of Set 6 | sao filipe
# Processing Record 37 of Set 6 | la ronge
# Processing Record 38 of Set 6 | harnosand
# Processing Record 39 of Set 6 | dunda
# Processing Record 40 of Set 6 | eyl
# Processing Record 41 of Set 6 | buala
# Processing Record 42 of Set 6 | kavieng
# Processing Record 43 of Set 6 | entebbe
# Processing Record 44 of Set 6 | trairi
# Processing Record 45 of Set 6 | kapuskasing
# Processing Record 46 of Set 6 | milkovo
# Processing Record 47 of Set 6 | labuhan
# Processing Record 48 of Set 6 | orange
# Processing Record 49 of Set 6 | paamiut
# Processing Record 50 of Set 6 | carutapera
# Processing Record 1 of Set 7 | paris
# Processing Record 2 of Set 7 | manpur
# Processing Record 3 of Set 7 | geraldton
# Processing Record 4 of Set 7 | najran
# Processing Record 5 of Set 7 | dauriya
# Processing Record 6 of Set 7 | los llanos de aridane
# Processing Record 7 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 7 | ormara
# Processing Record 9 of Set 7 | tambun
# Processing Record 10 of Set 7 | oboyan
# Processing Record 11 of Set 7 | porbandar
# Processing Record 12 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 7 | solnechnyy
# Processing Record 14 of Set 7 | ahmadpur sial
# Processing Record 15 of Set 7 | pahrump
# Processing Record 16 of Set 7 | severnyy
# Processing Record 17 of Set 7 | sinnamary
# Processing Record 18 of Set 7 | longyearbyen
# Processing Record 19 of Set 7 | saint george
# Processing Record 20 of Set 7 | zaraza
# Processing Record 21 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 7 | xuanwu
# Processing Record 23 of Set 7 | muros
# Processing Record 24 of Set 7 | tiarei
# Processing Record 25 of Set 7 | hofn
# Processing Record 26 of Set 7 | lichuan
# Processing Record 27 of Set 7 | karratha
# Processing Record 28 of Set 7 | pascagoula
# Processing Record 29 of Set 7 | skibbereen
# Processing Record 30 of Set 7 | honolulu
# Processing Record 31 of Set 7 | sabana abajo
# City not found. Skipping...
# Processing Record 32 of Set 7 | trinidad
# Processing Record 33 of Set 7 | hasaki
# Processing Record 34 of Set 7 | mangrol
# Processing Record 35 of Set 7 | vila franca do campo
# Processing Record 36 of Set 7 | nemuro
# Processing Record 37 of Set 7 | nata
# Processing Record 38 of Set 7 | toora-khem
# Processing Record 39 of Set 7 | coquimbo
# Processing Record 40 of Set 7 | los alamos
# Processing Record 41 of Set 7 | bahia honda
# Processing Record 42 of Set 7 | vanino
# Processing Record 43 of Set 7 | evensk
# Processing Record 44 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 7 | humberto de campos
# Processing Record 46 of Set 7 | mozarlandia
# Processing Record 47 of Set 7 | garowe
# Processing Record 48 of Set 7 | lasa
# Processing Record 49 of Set 7 | ongandjera
# Processing Record 50 of Set 7 | celestun
# Processing Record 1 of Set 8 | rorvik
# Processing Record 2 of Set 8 | atambua
# Processing Record 3 of Set 8 | cabo san lucas
# Processing Record 4 of Set 8 | wabrzezno
# Processing Record 5 of Set 8 | high rock
# Processing Record 6 of Set 8 | bridlington
# Processing Record 7 of Set 8 | sackville
# Processing Record 8 of Set 8 | balkhash
# Processing Record 9 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 8 | asau
# Processing Record 11 of Set 8 | gorontalo
# Processing Record 12 of Set 8 | kirakira
# Processing Record 13 of Set 8 | tura
# Processing Record 14 of Set 8 | zuenoula
# Processing Record 15 of Set 8 | acapulco
# Processing Record 16 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 17 of Set 8 | camabatela
# Processing Record 18 of Set 8 | matay
# Processing Record 19 of Set 8 | nyurba
# Processing Record 20 of Set 8 | clifton
# Processing Record 21 of Set 8 | millinocket
# Processing Record 22 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 8 | kudahuvadhoo
# Processing Record 24 of Set 8 | druzhba
# Processing Record 25 of Set 8 | arona
# Processing Record 26 of Set 8 | provideniya
# Processing Record 27 of Set 8 | port augusta
# Processing Record 28 of Set 8 | ilo
# Processing Record 29 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 8 | hovd
# Processing Record 31 of Set 8 | sundumbili
# Processing Record 32 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 8 | cabedelo
# Processing Record 34 of Set 8 | makung
# City not found. Skipping...
# Processing Record 35 of Set 8 | san cristobal
# Processing Record 36 of Set 8 | dera ismail khan
# Processing Record 37 of Set 8 | flin flon
# Processing Record 38 of Set 8 | talcahuano
# Processing Record 39 of Set 8 | mehamn
# Processing Record 40 of Set 8 | beisfjord
# Processing Record 41 of Set 8 | jurado
# Processing Record 42 of Set 8 | dhidhdhoo
# Processing Record 43 of Set 8 | mount gambier
# Processing Record 44 of Set 8 | santa cruz cabralia
# Processing Record 45 of Set 8 | salacgriva
# Processing Record 46 of Set 8 | marawi
# Processing Record 47 of Set 8 | husavik
# Processing Record 48 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 49 of Set 8 | westport
# Processing Record 50 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 9 | east bethel
# Processing Record 2 of Set 9 | itarema
# Processing Record 3 of Set 9 | rio cuarto
# Processing Record 4 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 9 | laurinburg
# Processing Record 6 of Set 9 | mantua
# Processing Record 7 of Set 9 | marystown
# Processing Record 8 of Set 9 | moerai
# Processing Record 9 of Set 9 | kieta
# Processing Record 10 of Set 9 | pavilosta
# Processing Record 11 of Set 9 | vao
# Processing Record 12 of Set 9 | goderich
# Processing Record 13 of Set 9 | malanje
# Processing Record 14 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 9 | zelenokumsk
# Processing Record 16 of Set 9 | takefu
# Processing Record 17 of Set 9 | dubbo
# Processing Record 18 of Set 9 | bambous virieux
# Processing Record 19 of Set 9 | kholm
# Processing Record 20 of Set 9 | prince rupert
# Processing Record 21 of Set 9 | sokolo
# Processing Record 22 of Set 9 | thinadhoo
# Processing Record 23 of Set 9 | eureka
# Processing Record 24 of Set 9 | samana
# Processing Record 25 of Set 9 | anapskaya
# Processing Record 26 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 9 | victor harbor
# Processing Record 28 of Set 9 | port shepstone
# Processing Record 29 of Set 9 | eenhana
# Processing Record 30 of Set 9 | bandundu
# Processing Record 31 of Set 9 | talnakh
# Processing Record 32 of Set 9 | houma
# Processing Record 33 of Set 9 | soloneshnoye
# Processing Record 34 of Set 9 | yar-sale
# Processing Record 35 of Set 9 | damara
# Processing Record 36 of Set 9 | hornepayne
# Processing Record 37 of Set 9 | tahe
# Processing Record 38 of Set 9 | svetlogorsk
# Processing Record 39 of Set 9 | hami
# Processing Record 40 of Set 9 | port hedland
# Processing Record 41 of Set 9 | aykhal
# Processing Record 42 of Set 9 | bambanglipuro
# Processing Record 43 of Set 9 | vrangel
# Processing Record 44 of Set 9 | yanam
# Processing Record 45 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 9 | ilhabela
# Processing Record 47 of Set 9 | saldanha
# Processing Record 48 of Set 9 | jiuquan
# Processing Record 49 of Set 9 | chulman
# Processing Record 50 of Set 9 | ndele
# Processing Record 1 of Set 10 | tignere
# Processing Record 2 of Set 10 | phan thiet
# Processing Record 3 of Set 10 | tacoronte
# Processing Record 4 of Set 10 | mae sot
# Processing Record 5 of Set 10 | ndjole
# Processing Record 6 of Set 10 | san vicente
# Processing Record 7 of Set 10 | buncrana
# Processing Record 8 of Set 10 | ozark
# Processing Record 9 of Set 10 | bose
# Processing Record 10 of Set 10 | saint-pierre
# Processing Record 11 of Set 10 | mareeba
# Processing Record 12 of Set 10 | mayo
# Processing Record 13 of Set 10 | ust-maya
# Processing Record 14 of Set 10 | prescott valley
# Processing Record 15 of Set 10 | marau
# Processing Record 16 of Set 10 | dikson
# Processing Record 17 of Set 10 | xining
# Processing Record 18 of Set 10 | werota
# Processing Record 19 of Set 10 | nantucket
# Processing Record 20 of Set 10 | beloha
# Processing Record 21 of Set 10 | punta de piedra
# Processing Record 22 of Set 10 | marathon
# Processing Record 23 of Set 10 | tandil
# Processing Record 24 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 10 | kijang
# Processing Record 26 of Set 10 | stepnyak
# Processing Record 27 of Set 10 | vila
# Processing Record 28 of Set 10 | villa florida
# Processing Record 29 of Set 10 | grand gaube
# Processing Record 30 of Set 10 | walvis bay
# Processing Record 31 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 10 | diapaga
# Processing Record 33 of Set 10 | south lake tahoe
# Processing Record 34 of Set 10 | changli
# Processing Record 35 of Set 10 | dingle
# Processing Record 36 of Set 10 | cerritos
# Processing Record 37 of Set 10 | balakhninskiy
# Processing Record 38 of Set 10 | san juan
# Processing Record 39 of Set 10 | broken hill
# Processing Record 40 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 41 of Set 10 | luba
# Processing Record 42 of Set 10 | royken
# Processing Record 43 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 44 of Set 10 | inuvik
# Processing Record 45 of Set 10 | margate
# Processing Record 46 of Set 10 | lakes entrance
# Processing Record 47 of Set 10 | rawson
# Processing Record 48 of Set 10 | aliaga
# Processing Record 49 of Set 10 | hit
# Processing Record 50 of Set 10 | henties bay
# Processing Record 1 of Set 11 | codrington
# Processing Record 2 of Set 11 | lazaro cardenas
# Processing Record 3 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 4 of Set 11 | slonim
# Processing Record 5 of Set 11 | les cayes
# Processing Record 6 of Set 11 | lyuban
# Processing Record 7 of Set 11 | okha
# Processing Record 8 of Set 11 | labrea
# Processing Record 9 of Set 11 | deputatskiy
# Processing Record 10 of Set 11 | jiujiang
# Processing Record 11 of Set 11 | valle hermoso
# Processing Record 12 of Set 11 | sao miguel do araguaia
# Processing Record 13 of Set 11 | peniche
# Processing Record 14 of Set 11 | isangel
# Processing Record 15 of Set 11 | santa fe
# Processing Record 16 of Set 11 | dehloran
# Processing Record 17 of Set 11 | paro
# Processing Record 18 of Set 11 | omboue
# Processing Record 19 of Set 11 | maridi
# Processing Record 20 of Set 11 | nalut
# Processing Record 21 of Set 11 | maua
# Processing Record 22 of Set 11 | almeria
# Processing Record 23 of Set 11 | destin
# Processing Record 24 of Set 11 | aasiaat
# Processing Record 25 of Set 11 | aguimes
# Processing Record 26 of Set 11 | cockburn town
# Processing Record 27 of Set 11 | olafsvik
# Processing Record 28 of Set 11 | suruc
# Processing Record 29 of Set 11 | nieves
# Processing Record 30 of Set 11 | airai
# Processing Record 31 of Set 11 | ancud
# Processing Record 32 of Set 11 | svetlyy
# Processing Record 33 of Set 11 | teneguiban
# City not found. Skipping...
# Processing Record 34 of Set 11 | ajdabiya
# Processing Record 35 of Set 11 | bandarbeyla
# Processing Record 36 of Set 11 | padang
# Processing Record 37 of Set 11 | limerick
# Processing Record 38 of Set 11 | majene
# Processing Record 39 of Set 11 | saint-junien
# Processing Record 40 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 11 | kununurra
# Processing Record 42 of Set 11 | maceio
# Processing Record 43 of Set 11 | kisangani
# Processing Record 44 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 45 of Set 11 | savannah bight
# Processing Record 46 of Set 11 | radomir
# Processing Record 47 of Set 11 | dongtai
# Processing Record 48 of Set 11 | nome
# Processing Record 49 of Set 11 | huilong
# Processing Record 50 of Set 11 | grindavik
# Processing Record 1 of Set 12 | methoni
# Processing Record 2 of Set 12 | bowen
# Processing Record 3 of Set 12 | te anau
# Processing Record 4 of Set 12 | berlevag
# Processing Record 5 of Set 12 | roches noires
# City not found. Skipping...
# Processing Record 6 of Set 12 | port-gentil
# Processing Record 7 of Set 12 | whitehorse
# Processing Record 8 of Set 12 | katsuura
# Processing Record 9 of Set 12 | tual
# Processing Record 10 of Set 12 | troy
# Processing Record 11 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 12 | san quintin
# Processing Record 13 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 14 of Set 12 | stornoway
# Processing Record 15 of Set 12 | mao
# Processing Record 16 of Set 12 | ust-omchug
# Processing Record 17 of Set 12 | lewistown
# Processing Record 18 of Set 12 | nabire
# Processing Record 19 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 12 | skjervoy
# Processing Record 21 of Set 12 | maldonado
# Processing Record 22 of Set 12 | sauda
# Processing Record 23 of Set 12 | hede
# Processing Record 24 of Set 12 | bilma
# Processing Record 25 of Set 12 | kasongo-lunda
# Processing Record 26 of Set 12 | teya
# Processing Record 27 of Set 12 | buchanan
# Processing Record 28 of Set 12 | basco
# Processing Record 29 of Set 12 | kyaikkami
# Processing Record 30 of Set 12 | ginir
# Processing Record 31 of Set 12 | mola di bari
# Processing Record 32 of Set 12 | sovetskaya
# Processing Record 33 of Set 12 | tres lagoas
# Processing Record 34 of Set 12 | kolosovka
# Processing Record 35 of Set 12 | betare oya
# Processing Record 36 of Set 12 | vila velha
# Processing Record 37 of Set 12 | chapais
# Processing Record 38 of Set 12 | paytug
# City not found. Skipping...
# Processing Record 39 of Set 12 | northam
# Processing Record 40 of Set 12 | faya
# Processing Record 41 of Set 12 | havoysund
# Processing Record 42 of Set 12 | xushan
# Processing Record 43 of Set 12 | lembeni
# Processing Record 44 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 12 | lata
# Processing Record 46 of Set 12 | nelson bay
# Processing Record 47 of Set 12 | ponta delgada
# Processing Record 48 of Set 12 | ban nahin
# Processing Record 49 of Set 12 | meulaboh
# Processing Record 50 of Set 12 | patun-an
# City not found. Skipping...
# Processing Record 1 of Set 13 | auki
# Processing Record 2 of Set 13 | huanren
# Processing Record 3 of Set 13 | grootfontein
# Processing Record 4 of Set 13 | tambacounda
# Processing Record 5 of Set 13 | pozzallo
# Processing Record 6 of Set 13 | letham
# Processing Record 7 of Set 13 | parakou
# Processing Record 8 of Set 13 | comodoro rivadavia
# Processing Record 9 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 13 | sherpur
# Processing Record 11 of Set 13 | aljezur
# Processing Record 12 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 13 of Set 13 | pokaran
# Processing Record 14 of Set 13 | constitucion
# Processing Record 15 of Set 13 | nampula
# Processing Record 16 of Set 13 | rypefjord
# Processing Record 17 of Set 13 | liverpool
# Processing Record 18 of Set 13 | sola
# Processing Record 19 of Set 13 | pisco
# Processing Record 20 of Set 13 | ca mau
# Processing Record 21 of Set 13 | sirsilla
# Processing Record 22 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 13 | pine bluff
# Processing Record 24 of Set 13 | genhe
# Processing Record 25 of Set 13 | praia da vitoria
# Processing Record 26 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 13 | high level
# Processing Record 28 of Set 13 | aksu
# Processing Record 29 of Set 13 | moramanga
# Processing Record 30 of Set 13 | wucheng
# Processing Record 31 of Set 13 | el alto
# Processing Record 32 of Set 13 | oranjemund
# Processing Record 33 of Set 13 | paralimni
# Processing Record 34 of Set 13 | alyangula
# Processing Record 35 of Set 13 | grand-santi
# Processing Record 36 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record 37 of Set 13 | daudnagar
# Processing Record 38 of Set 13 | taoudenni
# Processing Record 39 of Set 13 | macae
# Processing Record 40 of Set 13 | parkes
# Processing Record 41 of Set 13 | dzhebariki-khaya
# Processing Record 42 of Set 13 | kalengwa
# Processing Record 43 of Set 13 | batesville
# Processing Record 44 of Set 13 | tongliao
# Processing Record 45 of Set 13 | bagdarin
# Processing Record 46 of Set 13 | kloulklubed
# Processing Record 47 of Set 13 | kwekwe
# Processing Record 48 of Set 13 | brownsville
# Processing Record 49 of Set 13 | sioux lookout
# Processing Record 50 of Set 13 | balingasay
# Processing Record 1 of Set 14 | katha
# City not found. Skipping...
# Processing Record 2 of Set 14 | namatanai
# Processing Record 3 of Set 14 | hvide sande
# Processing Record 4 of Set 14 | saurimo
# Processing Record 5 of Set 14 | sollies-pont
# Processing Record 6 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 14 | gondanglegi
# Processing Record 8 of Set 14 | santa cruz de la palma
# Processing Record 9 of Set 14 | griffith
# Processing Record 10 of Set 14 | sakaraha
# Processing Record 11 of Set 14 | ixtapa
# Processing Record 12 of Set 14 | bereda
# Processing Record 13 of Set 14 | ewo
# Processing Record 14 of Set 14 | mafinga
# Processing Record 15 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 14 | zapolyarnyy
# Processing Record 17 of Set 14 | hakui
# Processing Record 18 of Set 14 | saint-louis
# Processing Record 19 of Set 14 | pombas
# Processing Record 20 of Set 14 | aracoiaba
# Processing Record 21 of Set 14 | kourou
# Processing Record 22 of Set 14 | hamcearca
# Processing Record 23 of Set 14 | kargasok
# Processing Record 24 of Set 14 | gazanjyk
# Processing Record 25 of Set 14 | kamenka
# Processing Record 26 of Set 14 | ulaangom
# Processing Record 27 of Set 14 | maki
# Processing Record 28 of Set 14 | zaozhuang
# Processing Record 29 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 30 of Set 14 | oxbow
# Processing Record 31 of Set 14 | torbay
# Processing Record 32 of Set 14 | menongue
# Processing Record 33 of Set 14 | namibe
# Processing Record 34 of Set 14 | buraydah
# Processing Record 35 of Set 14 | katangli
# Processing Record 36 of Set 14 | hervey bay
# Processing Record 37 of Set 14 | olinda
# Processing Record 38 of Set 14 | west wendover
# Processing Record 39 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 40 of Set 14 | minab
# Processing Record 41 of Set 14 | tsabong
# Processing Record 42 of Set 14 | vizinga
# Processing Record 43 of Set 14 | agadir
# Processing Record 44 of Set 14 | niquelandia
# Processing Record 45 of Set 14 | el dorado
# Processing Record 46 of Set 14 | kostino
# Processing Record 47 of Set 14 | dogondoutchi
# Processing Record 48 of Set 14 | yatou
# Processing Record 49 of Set 14 | manaure
# Processing Record 50 of Set 14 | moratuwa
# Processing Record 1 of Set 15 | boulder city
# Processing Record 2 of Set 15 | oranzherei
# Processing Record 3 of Set 15 | bouna
# Processing Record 4 of Set 15 | marsa matruh
# Processing Record 5 of Set 15 | santa cruz
# Processing Record 6 of Set 15 | esmeralda
# Processing Record 7 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 15 | muli
# Processing Record 9 of Set 15 | merrill
# Processing Record 10 of Set 15 | rantauprapat
# Processing Record 11 of Set 15 | siparia
# Processing Record 12 of Set 15 | hay river
# Processing Record 13 of Set 15 | plettenberg bay
# Processing Record 14 of Set 15 | burnie
# Processing Record 15 of Set 15 | luanda
# Processing Record 16 of Set 15 | pak phanang
# Processing Record 17 of Set 15 | mamatid
# Processing Record 18 of Set 15 | gamba
# Processing Record 19 of Set 15 | klang
# Processing Record 20 of Set 15 | bardiyah
# Processing Record 21 of Set 15 | sugag
# Processing Record 22 of Set 15 | batagay
# Processing Record 23 of Set 15 | qaqortoq
# Processing Record 24 of Set 15 | formosa
# Processing Record 25 of Set 15 | sumbawanga
# Processing Record 26 of Set 15 | ust-tsilma
# Processing Record 27 of Set 15 | buritis
# Processing Record 28 of Set 15 | turukhansk
# Processing Record 29 of Set 15 | buckeye
# Processing Record 30 of Set 15 | hof
# Processing Record 31 of Set 15 | marsaxlokk
# Processing Record 32 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 33 of Set 15 | haibowan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 664

# %%
# Adding data to DataFrame
city_data_df = pd.DataFrame(city_data)

# Changing the column order 
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[column_order]

city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Bredasdorp      ZA -34.5322   20.0403     43.29        88           0
# 1     Busselton      AU -33.6500  115.3333     60.35        72          41
# 2      Khatanga      RU  71.9667  102.5000     54.63        49         100
# 3   New Norfolk      AU -42.7826  147.0587     51.30        53           0
# 4       Qaanaaq      GL  77.4840  -69.3632     40.75        80         100
# 5       Ushuaia      AR -54.8000  -68.3000     29.86        86          75
# 6     Mahebourg      MU -20.4081   57.7000     67.24        69          86
# 7  Ponta Do Sol      PT  32.6667  -17.1000     72.72        65           9
# 8     Upernavik      GL  72.7868  -56.1549     48.76        67         100
# 9      Kalmunai      LK   7.4167   81.8167     85.42        68         100
#
#    Wind Speed Current Description
# 0        5.14           clear sky
# 1       17.18    scattered clouds
# 2       20.54     overcast clouds
# 3        2.10           clear sky
# 4        6.76     overcast clouds
# 5       13.80          light snow
# 6       21.61          light rain
# 7        6.96           clear sky
# 8        7.99     overcast clouds
# 9        1.32     overcast clouds

# %%
# Write DataFrame to CSV file.
city_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(city_data_file, index_label="City_ID")
